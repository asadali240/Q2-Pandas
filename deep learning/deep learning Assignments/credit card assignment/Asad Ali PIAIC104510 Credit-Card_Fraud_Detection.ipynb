# %% [markdown]
# # Credit Card Fraud Detection::

# %% [markdown]
# Download dataset from this link:
#
# https://www.kaggle.com/mlg-ulb/creditcardfraud

# %% [markdown]
# # Description about dataset::

# %% [markdown]
# The datasets contains transactions made by credit cards in September 2013 by european cardholders.
# This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.
#
# It contains only numerical input variables which are the result of a PCA transformation. Unfortunately, due to confidentiality issues, we cannot provide the original features and more background information about the data. Features V1, V2, … V28 are the principal components obtained with PCA, the only features which have not been transformed with PCA are 'Time' and 'Amount'. Feature 'Time' contains the seconds elapsed between each transaction and the first transaction in the dataset. The feature 'Amount' is the transaction Amount, this feature can be used for example-dependant cost-senstive learning.
#
#
# ### Feature 'Class' is the response variable and it takes value 1 in case of fraud and 0 otherwise.

# %% [markdown]
# # WORKFLOW :

# %% [markdown]
# 1.Load Data
#
# 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )
#
# 3.Standardized the Input Variables.
#
# 4.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
#
# 5.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#
# 6.Compilation Step (Note : Its a Binary problem , select loss , metrics according to it)
#
# 7.Train the Model with Epochs (100).
#
# 8.If the model gets overfit tune your model by changing the units , No. of layers , epochs , add dropout layer or add Regularizer according to the need .
#
# 9.Prediction should be > 92%
# 10.Evaluation Step
# 11Prediction

# %% [markdown]
# # Task::

# %% [markdown]
# ## Identify fraudulent credit card transactions.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# mount google drive in to your Colab enviornment
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/AI-Q2-learning-resources-master/D.L solve assignment
# Out:
# /content/drive/MyDrive/Colab Notebooks/AI-Q2-learning-resources-master/D.L solve assignment

# %%
df = pd.read_csv('./creditcard.csv')

# %%
#!pip install -U scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading https://files.pythonhosted.org/packages/f3/74/eb899f41d55f957e2591cde5528e75871f817d9fb46d4732423ecaca736d/scikit_learn-0.24.1-cp37-cp37m-manylinux2010_x86_64.whl (22.3MB)
#      |████████████████████████████████| 22.3MB 1.6MB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.4.1)
# Collecting threadpoolctl>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/f7/12/ec3f2e203afa394a149911729357aa48affc59c20e2c1c8297a60f33f133/threadpoolctl-2.1.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.0.1)
# Installing collected packages: threadpoolctl, scikit-learn
#   Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
# Successfully installed scikit-learn-0.24.1 threadpoolctl-2.1.0

# %%
df.head(5)
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
non_fraud=df[df["Class"]==0]
fraud = df[df["Class"]==1]
non_fraud=non_fraud.sample(3*fraud.shape[0])
data = fraud.append(non_fraud, ignore_index=True)
# data["Class"].value_counts()
x_data= data.drop(columns="Class", axis=0)
label = data["Class"]

# %%
train_data, test_data, train_labels, test_labels=train_test_split(x_data, label, test_size=0.3, random_state=1, stratify = label)

# %%
train_mean = train_data.mean(axis=0) # taking the mean of 
train_data -= train_mean
train_std = train_data.std(axis=0)
train_data /= train_std
test_data -= train_mean
test_data /= train_std

# %%
from keras import models,layers
from keras import regularizers

model = models.Sequential()
model.add(layers.Dense(20, activation='relu',kernel_regularizer=regularizers.l2(0.001), input_shape=(train_data.shape[1],)))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(10, activation='relu',kernel_regularizer=regularizers.l2(0.001)))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(8, activation='relu',kernel_regularizer=regularizers.l2(0.001)))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(6, activation='relu',kernel_regularizer=regularizers.l2(0.001)))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(loss= 'binary_crossentropy', optimizer= 'rmsprop', metrics=['accuracy'])

# %%
model.fit(train_data, train_labels, epochs=100,validation_split = 0.3)
# Out:
# Epoch 1/100
# 31/31 [==============================] - 4s 18ms/step - loss: 0.7895 - accuracy: 0.5934 - val_loss: 0.7246 - val_accuracy: 0.8430
# Epoch 2/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7390 - accuracy: 0.6750 - val_loss: 0.7034 - val_accuracy: 0.7802
# Epoch 3/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.7272 - accuracy: 0.6818 - val_loss: 0.6782 - val_accuracy: 0.7609
# Epoch 4/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.6974 - accuracy: 0.7551 - val_loss: 0.6555 - val_accuracy: 0.7440
# Epoch 5/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6824 - accuracy: 0.7638 - val_loss: 0.6297 - val_accuracy: 0.7560
# Epoch 6/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6893 - accuracy: 0.7422 - val_loss: 0.6035 - val_accuracy: 0.7585
# Epoch 7/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6514 - accuracy: 0.7731 - val_loss: 0.5826 - val_accuracy: 0.7633
# Epoch 8/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6084 - accuracy: 0.7777 - val_loss: 0.5543 - val_accuracy: 0.7754
# Epoch 9/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5832 - accuracy: 0.7736 - val_loss: 0.5180 - val_accuracy: 0.7802
# Epoch 10/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.6036 - accuracy: 0.7498 - val_loss: 0.4911 - val_accuracy: 0.8140
# Epoch 11/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.5256 - accuracy: 0.7926 - val_loss: 0.4509 - val_accuracy: 0.8237
# Epoch 12/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5338 - accuracy: 0.7922 - val_loss: 0.4165 - val_accuracy: 0.8551
# Epoch 13/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5544 - accuracy: 0.7724 - val_loss: 0.3923 - val_accuracy: 0.8720
# Epoch 14/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5379 - accuracy: 0.7937 - val_loss: 0.3838 - val_accuracy: 0.8744
# Epoch 15/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.5002 - accuracy: 0.8049 - val_loss: 0.3552 - val_accuracy: 0.8986
# Epoch 16/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4829 - accuracy: 0.8029 - val_loss: 0.3347 - val_accuracy: 0.9130
# Epoch 17/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4526 - accuracy: 0.8222 - val_loss: 0.3106 - val_accuracy: 0.9203
# Epoch 18/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4747 - accuracy: 0.8023 - val_loss: 0.2980 - val_accuracy: 0.9275
# Epoch 19/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.4654 - accuracy: 0.8089 - val_loss: 0.2805 - val_accuracy: 0.9348
# Epoch 20/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4830 - accuracy: 0.8324 - val_loss: 0.2653 - val_accuracy: 0.9396
# Epoch 21/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4437 - accuracy: 0.8129 - val_loss: 0.2546 - val_accuracy: 0.9420
# Epoch 22/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4272 - accuracy: 0.8233 - val_loss: 0.2458 - val_accuracy: 0.9420
# Epoch 23/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3971 - accuracy: 0.8474 - val_loss: 0.2368 - val_accuracy: 0.9444
# Epoch 24/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4334 - accuracy: 0.8454 - val_loss: 0.2293 - val_accuracy: 0.9469
# Epoch 25/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.4217 - accuracy: 0.8368 - val_loss: 0.2238 - val_accuracy: 0.9517
# Epoch 26/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4043 - accuracy: 0.8452 - val_loss: 0.2183 - val_accuracy: 0.9517
# Epoch 27/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4311 - accuracy: 0.8318 - val_loss: 0.2151 - val_accuracy: 0.9517
# Epoch 28/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3803 - accuracy: 0.8512 - val_loss: 0.2112 - val_accuracy: 0.9517
# Epoch 29/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4099 - accuracy: 0.8477 - val_loss: 0.2074 - val_accuracy: 0.9517
# Epoch 30/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3829 - accuracy: 0.8352 - val_loss: 0.2037 - val_accuracy: 0.9493
# Epoch 31/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3751 - accuracy: 0.8737 - val_loss: 0.2013 - val_accuracy: 0.9517
# Epoch 32/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.3535 - accuracy: 0.8760 - val_loss: 0.2001 - val_accuracy: 0.9517
# Epoch 33/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.4010 - accuracy: 0.8430 - val_loss: 0.1989 - val_accuracy: 0.9517
# Epoch 34/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3253 - accuracy: 0.8904 - val_loss: 0.1974 - val_accuracy: 0.9541
# Epoch 35/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.3659 - accuracy: 0.8625 - val_loss: 0.1963 - val_accuracy: 0.9565
# Epoch 36/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3316 - accuracy: 0.8776 - val_loss: 0.1944 - val_accuracy: 0.9589
# Epoch 37/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3711 - accuracy: 0.8612 - val_loss: 0.1938 - val_accuracy: 0.9589
# Epoch 38/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3766 - accuracy: 0.8788 - val_loss: 0.1938 - val_accuracy: 0.9589
# Epoch 39/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3203 - accuracy: 0.8869 - val_loss: 0.1955 - val_accuracy: 0.9565
# Epoch 40/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.3421 - accuracy: 0.8790 - val_loss: 0.1945 - val_accuracy: 0.9589
# Epoch 41/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3713 - accuracy: 0.8868 - val_loss: 0.1948 - val_accuracy: 0.9589
# Epoch 42/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.3753 - accuracy: 0.8687 - val_loss: 0.1910 - val_accuracy: 0.9589
# Epoch 43/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3338 - accuracy: 0.8752 - val_loss: 0.1921 - val_accuracy: 0.9589
# Epoch 44/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3520 - accuracy: 0.8767 - val_loss: 0.1936 - val_accuracy: 0.9589
# Epoch 45/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3243 - accuracy: 0.8863 - val_loss: 0.1949 - val_accuracy: 0.9589
# Epoch 46/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3135 - accuracy: 0.8953 - val_loss: 0.1913 - val_accuracy: 0.9589
# Epoch 47/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.3051 - accuracy: 0.8918 - val_loss: 0.1929 - val_accuracy: 0.9614
# Epoch 48/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3444 - accuracy: 0.8685 - val_loss: 0.1961 - val_accuracy: 0.9614
# Epoch 49/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3032 - accuracy: 0.8859 - val_loss: 0.1942 - val_accuracy: 0.9614
# Epoch 50/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3065 - accuracy: 0.8745 - val_loss: 0.1986 - val_accuracy: 0.9614
# Epoch 51/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.3176 - accuracy: 0.9022 - val_loss: 0.1960 - val_accuracy: 0.9614
# Epoch 52/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2830 - accuracy: 0.9133 - val_loss: 0.1968 - val_accuracy: 0.9614
# Epoch 53/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.2909 - accuracy: 0.8940 - val_loss: 0.1963 - val_accuracy: 0.9589
# Epoch 54/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.3122 - accuracy: 0.8706 - val_loss: 0.2008 - val_accuracy: 0.9589
# Epoch 55/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3288 - accuracy: 0.8956 - val_loss: 0.1992 - val_accuracy: 0.9589
# Epoch 56/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2983 - accuracy: 0.8706 - val_loss: 0.2016 - val_accuracy: 0.9614
# Epoch 57/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2734 - accuracy: 0.8941 - val_loss: 0.2007 - val_accuracy: 0.9589
# Epoch 58/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4101 - accuracy: 0.8730 - val_loss: 0.1976 - val_accuracy: 0.9614
# Epoch 59/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.3011 - accuracy: 0.8831 - val_loss: 0.1985 - val_accuracy: 0.9589
# Epoch 60/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2776 - accuracy: 0.8939 - val_loss: 0.2006 - val_accuracy: 0.9589
# Epoch 61/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2734 - accuracy: 0.8973 - val_loss: 0.2030 - val_accuracy: 0.9589
# Epoch 62/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.3309 - accuracy: 0.8681 - val_loss: 0.1996 - val_accuracy: 0.9589
# Epoch 63/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2447 - accuracy: 0.9087 - val_loss: 0.1993 - val_accuracy: 0.9589
# Epoch 64/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2345 - accuracy: 0.8974 - val_loss: 0.2019 - val_accuracy: 0.9614
# Epoch 65/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2539 - accuracy: 0.8995 - val_loss: 0.2034 - val_accuracy: 0.9614
# Epoch 66/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3077 - accuracy: 0.8750 - val_loss: 0.2026 - val_accuracy: 0.9614
# Epoch 67/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.2938 - accuracy: 0.8782 - val_loss: 0.1998 - val_accuracy: 0.9614
# Epoch 68/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.2498 - accuracy: 0.9001 - val_loss: 0.1991 - val_accuracy: 0.9614
# Epoch 69/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2675 - accuracy: 0.8898 - val_loss: 0.1998 - val_accuracy: 0.9614
# Epoch 70/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.2762 - accuracy: 0.8959 - val_loss: 0.1984 - val_accuracy: 0.9614
# Epoch 71/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2896 - accuracy: 0.8686 - val_loss: 0.1992 - val_accuracy: 0.9614
# Epoch 72/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2611 - accuracy: 0.9034 - val_loss: 0.2032 - val_accuracy: 0.9614
# Epoch 73/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2827 - accuracy: 0.8796 - val_loss: 0.2092 - val_accuracy: 0.9614
# Epoch 74/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.2589 - accuracy: 0.9144 - val_loss: 0.2054 - val_accuracy: 0.9614
# Epoch 75/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2857 - accuracy: 0.8802 - val_loss: 0.2011 - val_accuracy: 0.9614
# Epoch 76/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.2917 - accuracy: 0.8845 - val_loss: 0.2052 - val_accuracy: 0.9614
# Epoch 77/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3258 - accuracy: 0.8826 - val_loss: 0.2005 - val_accuracy: 0.9638
# Epoch 78/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2770 - accuracy: 0.8907 - val_loss: 0.1975 - val_accuracy: 0.9638
# Epoch 79/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.2571 - accuracy: 0.9054 - val_loss: 0.2027 - val_accuracy: 0.9638
# Epoch 80/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2857 - accuracy: 0.8944 - val_loss: 0.2000 - val_accuracy: 0.9638
# Epoch 81/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2584 - accuracy: 0.9067 - val_loss: 0.2003 - val_accuracy: 0.9638
# Epoch 82/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2231 - accuracy: 0.9103 - val_loss: 0.2055 - val_accuracy: 0.9638
# Epoch 83/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2634 - accuracy: 0.8828 - val_loss: 0.2124 - val_accuracy: 0.9638
# Epoch 84/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3205 - accuracy: 0.8765 - val_loss: 0.2113 - val_accuracy: 0.9638
# Epoch 85/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.2435 - accuracy: 0.8871 - val_loss: 0.2143 - val_accuracy: 0.9638
# Epoch 86/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2175 - accuracy: 0.9123 - val_loss: 0.2173 - val_accuracy: 0.9638
# Epoch 87/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2345 - accuracy: 0.8991 - val_loss: 0.2188 - val_accuracy: 0.9638
# Epoch 88/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2932 - accuracy: 0.8879 - val_loss: 0.2085 - val_accuracy: 0.9638
# Epoch 89/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2179 - accuracy: 0.9119 - val_loss: 0.2048 - val_accuracy: 0.9638
# Epoch 90/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.2993 - accuracy: 0.8753 - val_loss: 0.2001 - val_accuracy: 0.9638
# Epoch 91/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.2130 - accuracy: 0.9173 - val_loss: 0.2085 - val_accuracy: 0.9638
# Epoch 92/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.2754 - accuracy: 0.8913 - val_loss: 0.2076 - val_accuracy: 0.9638
# Epoch 93/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2705 - accuracy: 0.8829 - val_loss: 0.2070 - val_accuracy: 0.9638
# Epoch 94/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1977 - accuracy: 0.9154 - val_loss: 0.2103 - val_accuracy: 0.9638
# Epoch 95/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2545 - accuracy: 0.8789 - val_loss: 0.2134 - val_accuracy: 0.9638
# Epoch 96/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2295 - accuracy: 0.8942 - val_loss: 0.2195 - val_accuracy: 0.9638
# Epoch 97/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.2620 - accuracy: 0.8990 - val_loss: 0.2145 - val_accuracy: 0.9614
# Epoch 98/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2221 - accuracy: 0.9129 - val_loss: 0.2100 - val_accuracy: 0.9614
# Epoch 99/100
# 31/31 [==============================] - 0s 5ms/step - loss: 0.2342 - accuracy: 0.9090 - val_loss: 0.2095 - val_accuracy: 0.9638
# Epoch 100/100
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2250 - accuracy: 0.8823 - val_loss: 0.2130 - val_accuracy: 0.9638

# %%
loss, accuracy = model.evaluate(test_data, test_labels)
# Out:
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2351 - accuracy: 0.9509

# %%
display (loss)
# Out:
# 0.2351130247116089

# %%
display (accuracy)
# Out:
# 0.950930655002594

# %%
x = model.predict(test_data).astype(dtype="u8")

# %%
a=x

# %%
b= np.array(test_labels)

# %%
a= a.reshape(1,a.shape[0])

# %%
np.size(a != b) - np.count_nonzero(a == b)
# Out:
# 100

# %%
con = tf.math.confusion_matrix(labels= test_labels, predictions=x )

# %%
display (con)
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[443,   0],
#        [100,  48]], dtype=int32)>
